# %%
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
import pandas as pd
from sklearn import preprocessing

# %%
#iris = datasets.load_iris()
data = {'size':['Large', 'Large', 'Medium', 'Large', 'Small', 'Large', 'Small', 'Small'],
        'sweet' :['Very', 'Very', 'Very', 'Mild', 'Medium', 'Very', 'Mild', 'Mild'],
        'choc' :['Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N'],
        'class' : [1,0,0,1,0,1,1,0]}
df = pd.DataFrame(data)
le = preprocessing.LabelEncoder()
#le.fit([["size,"sweet","choc"]])
print(df)

les = {'size': preprocessing.LabelEncoder(),
       'sweet': preprocessing.LabelEncoder(),
       'choc': preprocessing.LabelEncoder() }

for name, le in les.items():
  le.fit(data[name])

les
# Out:
#      size   sweet choc  class
# 0   Large    Very    Y      1
# 1   Large    Very    N      0
# 2  Medium    Very    N      0
# 3   Large    Mild    Y      1
# 4   Small  Medium    Y      0
# 5   Large    Very    Y      1
# 6   Small    Mild    Y      1
# 7   Small    Mild    N      0
# {'choc': LabelEncoder(), 'size': LabelEncoder(), 'sweet': LabelEncoder()}

# %%
for name, le in les.items():
  df[name + '_'] = le.fit_transform(df[name])
df
# Out:
#      size   sweet choc  class  size_  sweet_  choc_
# 0   Large    Very    Y      1      0       2      1
# 1   Large    Very    N      0      0       2      0
# 2  Medium    Very    N      0      1       2      0
# 3   Large    Mild    Y      1      0       1      1
# 4   Small  Medium    Y      0      2       0      1
# 5   Large    Very    Y      1      0       2      1
# 6   Small    Mild    Y      1      2       1      1
# 7   Small    Mild    N      0      2       1      0

# %%
X = df[['size_', 'sweet_', 'choc_']]
X
# Out:
#    size_  sweet_  choc_
# 0      0       2      1
# 1      0       2      0
# 2      1       2      0
# 3      0       1      1
# 4      2       0      1
# 5      0       2      1
# 6      2       1      1
# 7      2       1      0

# %%
clf = DecisionTreeClassifier(criterion= 'entropy')
model = clf.fit(X, y)

# %%
model
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1234, splitter='best')

# %%
fig = plt.figure(figsize=(10,8))
_ = tree.plot_tree(clf)

# %%
from math import log

base = 2

- 1/2 * log(9)
# Out:
# -1.0986122886681098

# %%
help(log)
# Out:
# Help on built-in function log in module math:
#
# log(...)
#     log(x, [base=math.e])
#     Return the logarithm of x to the given base.
#
#     If the base not specified, returns the natural logarithm (base e) of x.
